# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import seaborn as sns

# %%
sns.set_context('poster', font_scale=1.25)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from LB_D2Q9 import pipe_cython as lb

# %%
sim = lb.Pipe_Flow(lx=400, ly=400, tau=5)

# %%
sim.run(1000)

# %%
sim.u
# Out:
# array([[  2.21669069e-07,   4.21392906e-05,   1.26214756e-04, ...,
#           1.25624734e-04,   4.13192247e-05,  -3.51112249e-05],
#        [ -3.72528710e-08,   3.28458736e-05,   1.16348296e-04, ...,
#           1.20019169e-04,   3.63065410e-05,  -1.76653666e-05],
#        [ -3.72529172e-08,   5.14482126e-05,   1.35336348e-04, ...,
#           1.32048066e-04,   4.78455950e-05,  -1.59070187e-05],
#        ...,
#        [ -1.53556084e-05,   5.11931175e-05,   1.35094364e-04, ...,
#           1.32560512e-04,   4.82722535e-05,   0.00000000e+00],
#        [ -1.70617914e-05,   3.28311362e-05,   1.16335716e-04, ...,
#           1.19917109e-04,   3.61465209e-05,   0.00000000e+00],
#        [ -3.39110047e-05,   4.17154988e-05,   1.25809631e-04, ...,
#           1.26585684e-04,   4.21492587e-05,   2.21640448e-07]], dtype=float32)

# %%
velocity_magnitude = np.sqrt(sim.u**2 + sim.v**2)

plt.imshow(velocity_magnitude)
plt.grid(False)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7ff698b1dc68>

# %%
plt.plot(velocity_magnitude[50, :])

# %% [markdown]
# Well, this is promising. Excellent.
