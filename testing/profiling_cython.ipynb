# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import seaborn as sns

# %%
sns.set_context('poster', font_scale=1.25)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from LB_D2Q9 import pipe_cython as lb

# %% [markdown]
# We now want to visualize the evolution of the flow...let's see how it goes...

# %%
from IPython import display

# %% [markdown]
# It's probably easier to specify dt and dr and the dimensions. Then get everything else from that...yeah. That way the velocity is on the scale of U ~ 0.1 or so.

# %%
#### Input to the simulation in SI. ######
diameter = 4. # meters
length = 10. # meters

deltaP = -0.2

dr = 0.01
dt = 4.

viscosity = 10.**-6. # More viscous = easier to simulate!

##### Derived parameters ######
print 'Desired viscosity:' , viscosity
#Re = (input_velocity * diameter)/viscosity
#print 'Desired Re', Re

# Re is set by diameter, input_velocity, and viscosity
# Adjust dr so that mach number doers not explode!
print
print '###### Simulation Parameters #########'
print

# Solve for the desired omega...make sure it's in the correct range.


ly = int(np.ceil(diameter/dr))
lx = int(np.ceil(length/dr))
print 'ly', ly
print 'lx', lx

nx = lx + 1
ny = ly + 1

omega = .5 + (3*dt*viscosity)/(dr**2)

print 'omega:' , omega

assert (omega > 0.5) and (omega < 1)

obstacle_size=.25 # meters
# Out:
# Desired viscosity: 1e-06
#
# ###### Simulation Parameters #########
#
# ly 400
# lx 1000
# omega: 0.62

# %%
import skimage as ski
import skimage.draw

# %%
circle_center = np.array([2., 2.])
radius = .3

nondim_center = (circle_center/dr).astype(np.int)
nondim_radius = radius/dr

circle = ski.draw.circle(nondim_center[0], nondim_center[1], nondim_radius)

# %%
# Create the obstacle

obstacles = np.zeros((nx, ny), dtype=bool)
obstacles[circle[0], circle[1]] = True
plt.imshow(obstacles.T)
plt.grid(False)

# %%
sim = lb.Pipe_Flow_Obstacles(lx=lx, ly=ly, dr=dr, dt=dt, omega=omega,
                  deltaP = deltaP, obstacle_mask = obstacles)

# U should be on the order of 0.1, 0.2 in the simulation!
#print 'u_max in simulation:' , np.max(sim.u)

# %%
# %load_ext line_profiler

# %%
plt.imshow(np.sum(sim.f, axis=0).T)
plt.grid(False)

# %%
# %%prun 

sim.run(100)

# %% [raw]
# Here is the output:
# 3103 function calls in 12.489 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       100    7.760    0.078    7.760    0.078 pipe_cython.pyx:97(update_feq)
#       100    2.066    0.021    2.066    0.021 pipe_cython.pyx:251(collide_particles)
#       100    1.296    0.013    1.296    0.013 pipe_cython.pyx:214(move)
#       100    0.995    0.010    1.298    0.013 pipe_cython.pyx:125(update_hydro)
#       100    0.301    0.003    0.301    0.003 {method 'reduce' of 'numpy.ufunc' objects}
#       100    0.029    0.000    1.326    0.013 pipe_cython.pyx:280(update_hydro)
#       100    0.027    0.000    0.028    0.000 pipe_cython.pyx:150(move_bcs)
#       100    0.008    0.000    0.037    0.000 pipe_cython.pyx:285(move_bcs)
#         1    0.003    0.003   12.489   12.489 pipe_cython.pyx:258(run)
#       500    0.001    0.000    0.001    0.000 stringsource:319(__cinit__)
#       100    0.001    0.000    0.303    0.003 fromnumeric.py:1733(sum)
#       100    0.001    0.000    0.001    0.000 {isinstance}
#       500    0.001    0.000    0.002    0.000 stringsource:615(memoryview_cwrapper)
#       100    0.000    0.000    0.301    0.003 _methods.py:31(_sum)
#       500    0.000    0.000    0.000    0.000 stringsource:341(__dealloc__)
#       500    0.000    0.000    0.000    0.000 stringsource:621(memoryview_check)
#         1    0.000    0.000   12.489   12.489 <string>:3(<module>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
# So, the slowest pieces are actually the array pieces, i.e. updating the feq's and colliding the particles. Not the moving, which is what I thought would do it. So, we need to parallelize those pieces. The are by far the slowest. If we can reduce them by about an order of magnitude we will be all set.

# %%
total_num_steps = 5000
steps_per_image= 25

num_to_record = int(np.ceil(float(total_num_steps)/steps_per_image))

Re_list = []
Ma_list = []

plt.figure()
for i in range(num_to_record):
    sim.update_dimensionless_nums()
    Re_list.append(sim.Re)
    Ma_list.append(sim.Ma)
    print 'max non_dim u:', np.max(sim.u)
    print 'sum of mass' , np.sum(sim.rho)/(sim.nx*sim.ny)
    mag = np.sqrt(sim.u**2 + sim.v**2)
    plt.imshow(mag.T, cmap = cm.coolwarm)
    plt.grid(False)
    #plt.clim(vmin=0, vmax=1.)
    #if i == 0:
    #    plt.colorbar()
    display.clear_output(wait=True)
    display.display(plt.gcf())
    
    sim.run(steps_per_image)
plt.clf() # This way a second figure does not appear at the end...
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-28c60104997d> in <module>()
#      23     display.display(plt.gcf())
#      24
# ---> 25     sim.run(steps_per_image)
#      26 plt.clf() # This way a second figure does not appear at the end...
#
# /home/bryan/git/2d-lb/LB_D2Q9/pipe_cython.pyx in LB_D2Q9.pipe_cython.Pipe_Flow.run (LB_D2Q9/pipe_cython.c:8360)()
#     259             self.move_bcs() # We have to udpate the boundary conditions first, or we are in trouble.
#     260             self.move() # Move all jumpers
# --> 261             self.update_hydro() # Update the hydrodynamic variables
#     262             self.update_feq() # Update the equilibrium fields
#     263             self.collide_particles() # Relax the nonequilibrium fields
#
# /home/bryan/git/2d-lb/LB_D2Q9/pipe_cython.pyx in LB_D2Q9.pipe_cython.Pipe_Flow_Obstacles.update_hydro (LB_D2Q9/pipe_cython.c:8865)()
#     278
#     279     def update_hydro(self):
# --> 280         super(Pipe_Flow_Obstacles, self).update_hydro()
#     281         self.u[self.obstacle_mask] = 0
#     282         self.v[self.obstacle_mask] = 0
#
# /home/bryan/git/2d-lb/LB_D2Q9/pipe_cython.pyx in LB_D2Q9.pipe_cython.Pipe_Flow.update_hydro (LB_D2Q9/pipe_cython.c:4080)()
#     126
#     127         rho = self.rho
# --> 128         rho[:, :] = np.sum(f, axis=0)
#     129         inverse_rho = 1./self.rho
#     130
#
# /home/bryan/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in sum(a, axis, dtype, out, keepdims)
#    1731
#    1732
# -> 1733 def sum(a, axis=None, dtype=None, out=None, keepdims=False):
#    1734     """
#    1735     Sum of array elements over a given axis.
#
# KeyboardInterrupt:

# %% [markdown]
# IDK how to convert...but let's just fit.

# %%
plt.semilogy(Ma_list, ls='-', marker='.')

# %% [markdown]
# Nope, it's fucked! lol.

# %%
plt.semilogy(Re_list, ls='-', marker='.')

# %% [markdown]
# Looks like it still hasn't converged. But, as expected, larger pressure differences leads to larger reynolds numbers!
